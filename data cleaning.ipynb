# %% [markdown]
# # Data Cleaning in Pandas

# %% [markdown]
# ## Data cleaning mainly means:
#
# ## Handling missing values
#  ## Removing duplicates
#  ## Fixing wrong data types

# %% [markdown]
# # 1. Detecting Missing Values

# %%
import pandas as pd

# %%
import numpy as np

# %%
data = {
    "Name": ["Ali", "Sara", "John", None],
    "Age": [22, np.nan, 25, 24],
    "Salary": [50000, 60000, np.nan, 52000]
}

# %%
data
# Out:
# {'Name': ['Ali', 'Sara', 'John', None],
#  'Age': [22, nan, 25, 24],
#  'Salary': [50000, 60000, nan, 52000]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    Name   Age   Salary
# 0   Ali  22.0  50000.0
# 1  Sara   NaN  60000.0
# 2  John  25.0      NaN
# 3  None  24.0  52000.0

# %% [markdown]
# ## note: isnull() and isna() are same

# %%
df.isnull()
# Out:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2  False  False    True
# 3   True  False   False

# %%
df.isna()
# Out:
#     Name    Age  Salary
# 0  False  False   False
# 1  False   True   False
# 2  False  False    True
# 3   True  False   False

# %%
df.isnull().sum()
# Out:
# Name      1
# Age       1
# Salary    1
# dtype: int64

# %%
df.isnull().any()
# Out:
# Name      True
# Age       True
# Salary    True
# dtype: bool

# %% [markdown]
# # 2.  Removing Missing Values

# %% [markdown]
# ## dropna()
# ## Removes rows (or columns) with missing values.

# %%
df_dropped=df.dropna()

# %%
df_dropped
# Out:
#   Name   Age   Salary
# 0  Ali  22.0  50000.0

# %%
df_drop=df.dropna(axis=1)

# %%
df_drop
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
df.dropna(how="all")
# Out:
#    Name   Age   Salary
# 0   Ali  22.0  50000.0
# 1  Sara   NaN  60000.0
# 2  John  25.0      NaN
# 3  None  24.0  52000.0

# %% [markdown]
# # 3. Filling Missing Values

# %%
df.fillna(0)
# Out:
#    Name   Age   Salary
# 0   Ali  22.0  50000.0
# 1  Sara   0.0  60000.0
# 2  John  25.0      0.0
# 3     0  24.0  52000.0

# %% [markdown]
# ## Fill using MEAN / MEDIAN / MODE

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())

# %%
df["Salary"] = df["Salary"].fillna(df["Salary"].median())

# %%
df
# Out:
#    Name        Age   Salary
# 0   Ali  22.000000  50000.0
# 1  Sara  23.666667  60000.0
# 2  John  25.000000  52000.0
# 3  None  24.000000  52000.0

# %% [markdown]
# ## Fill using mode

# %%
df["Name"] = df["Name"].fillna(df["Name"].mode()[0])

# %%
df
# Out:
#    Name        Age   Salary
# 0   Ali  22.000000  50000.0
# 1  Sara  23.666667  60000.0
# 2  John  25.000000  52000.0
# 3   Ali  24.000000  52000.0

# %% [markdown]
# # 4. Duplicate Data

# %% [markdown]
# ## Duplicates can harm ML models.

# %%
data2 = {
    "ID": [1, 2, 2, 3],
    "Product": ["Phone", "Laptop", "Laptop", "Tablet"],
    "Price": [30000, 50000, 50000, 20000]
}

# %%
df1=pd.DataFrame(data2)

# %%
df1
# Out:
#    ID Product  Price
# 0   1   Phone  30000
# 1   2  Laptop  50000
# 2   2  Laptop  50000
# 3   3  Tablet  20000

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# dtype: bool

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Salary]
# Index: []

# %%
df_clean=df.drop_duplicates()

# %%
df_clean
# Out:
#    Name        Age   Salary
# 0   Ali  22.000000  50000.0
# 1  Sara  23.666667  60000.0
# 2  John  25.000000  52000.0
# 3   Ali  24.000000  52000.0
